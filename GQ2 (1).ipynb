# %%
from re import A
import math
print("Bienvenido a la calculadora de caida libre")
print("¿Qué operación deseas realizar?\n1.Altura\n2.Velocidad final\n3.Tiempo")
eleccion=int(input("Seleccione una opcion: "))
if eleccion==1:
     T=int(input("¿Ya tiene el tiempo en segundos? \n1.si\n2.No  "))
     if T==1:
       x=int(input("Ingrese el tiempo de caida en segundos: "))
       print(f"\nla altura de caida es de {(9.81*(x*x))/2} Metros")
     else:
       A=int(input("Seleccione la forma de tiempo en que la tiene: \n1.Hora\n2.minutos"))
       if A==1:
         p=int(input("Ingrese el tiempo en horas: "))
         print(f"\nla altura de caida es de {(((p*60*60)**2)*9.81)/2} Metros")
       elif A==2:
         r=int(input("Ingrese el tiempo en minutos: "))
         print(f"\nla altura de caida es de {(((r*60)**2)*9.81)/2} Metros")




if eleccion==2:
  Vf=int(input("¿Porqué método lo hara?:\n1.√2gh\n2.gt "))
  if Vf==1:
     Q=int(input("¿Ya tiene la altura en metros? \n1.si\n2.No  "))
     if Q==1:
      z=int(input("Ingrese la altura en metros: "))
      print(f"La velocidad final es: {round(math.sqrt((2*z*9.81,2)))} M/s")
     elif Q==2:
       c=int(input("Seleccione en que forma lo tiene: \n1.Km\n2.Hm\n3.Dm\n4.dm\n5.cm\n6.mm"))
       if c==1:
         c1=int(input("Ingrese los kilometros: "))
         print(f"La velocidad final es: {round(math.sqrt((2*(c1*1000)*9.81)))} M/s")
       elif c==2:
         c2=int(input("Ingrese los hectometros: "))
         print(f"La velocidad final es: {round(math.sqrt((2*(c2*100)*9.81)))} M/s")
       elif c==3:
          c3=int(input("Ingrese los decametros: ")) 
          print(f"La velocidad final es: {round(math.sqrt((2*(c3*10)*9.81)))} M/s")
       elif c==4:
         c4=int(input("Ingrese los decimetros: ")) 
         print(f"La velocidad final es: {round(math.sqrt((2*(c4/10)*9.81)))} M/s")
       elif c==5:
         c5=int(input("Ingrese los centimetros: ")) 
         print(f"La velocidad final es: {round(math.sqrt((2*(c5/100)*9.81)))} M/s")
       elif c==6:
         c6=int(input("Ingrese los centimetros: ")) 
         print(f"La velocidad final es: {round(math.sqrt((2*(c6/1000)*9.81)))} M/s")  


  elif Vf==2:
    o=int(input("¿Ya tiene el tiempo en segundos? \n1.si\n2.No  "))
    if o==1:
      h=int(input("Ingrese el tiempo en segundos: "))
      print(f"La velocidad final es: {9.81*h} M/s")
    elif o==2:
       j=int(input("Seleccione la forma de tiempo en que la tiene: \n1.Hora\n2.minutos"))
       if j==1:
         m=int(input("Ingrese el tiempo en horas: "))
         print(f"\nla altura de caida es de {(m*60*60)*9.81} M/s")
       elif j==2:
         n=int(input("Ingrese el tiempo en minutos: "))
         print(f"\nla altura de caida es de {(n*60)*9.81} M/s")

if eleccion==3:
      tm=int(input("¿Porqué método lo hara?:\n1.√(2h/g)\n2.Vf/g  "))
      if tm==1:
         l=int(input("¿Ya tiene la altura en metros? \n1.si\n2.No  "))
         if l==1:
          s=int(input("Ingrese la altura en metros: "))
          print(f"El tiempo de caida es: {round(math.sqrt((2*s)/9.81,2))} segundos")
         elif l==2:
            c=int(input("Seleccione en que forma lo tiene: \n1.Km\n2.Hm\n3.Dm\n4.dm\n5.cm\n6.mm"))
         if c==1:
            c1=int(input("Ingrese los kilometros: "))
            print(f"La velocidad final es: {round(math.sqrt((2*(c1*1000)/9.81)))} M/s")
         elif c==2:
            c2=int(input("Ingrese los hectometros: "))
            print(f"La velocidad final es: {round(math.sqrt((2*(c2*100)/9.81)))} M/s")
         elif c==3:
             c3=int(input("Ingrese los decametros: ")) 
             print(f"La velocidad final es: {round(math.sqrt((2*(c3*10)/9.81)))} M/s")
         elif c==4:
             c4=int(input("Ingrese los decimetros: ")) 
             print(f"La velocidad final es: {round(math.sqrt((2*(c4/10)/9.81)))} M/s")
         elif c==5:
             c5=int(input("Ingrese los centimetros: ")) 
             print(f"La velocidad final es: {round(math.sqrt((2*(c5/100)/9.81)))} M/s")
         elif c==6:
             c6=int(input("Ingrese los centimetros: ")) 
             print(f"La velocidad final es: {round(math.sqrt((2*(c6/1000)/9.81)))} M/s")


      elif tm==2:
        b=int(input("Seleccione el tipo de velocidad que tiene: \n1.M/s\n2.KM/h  "))
        if b==1:
         f=int(input("Ingrese la velocidad final en M/s: "))
         print(f"El tiempo de caida es de: {round(f/9.81,2)} segundos")
        elif b==2:
          v=int(input("Ingrese la velocidad final en Km/h:  "))
          print(f"El tiempo de caida es de: {round((v*(1000/3600))/9.81,2)} segundos")




print("\nGracias por utilizar nuestros servicios, siguenos en instagram como ARMITH16 <3")
# Out:
# Bienvenido a la calculadora de caida libre
# ¿Qué operación deseas realizar?
# 1.Altura
# 2.Velocidad final
# 3.Tiempo
# Seleccione una opcion: 3
# ¿Porqué método lo hara?:
# 1.√(2h/g)
# 2.Vf/g  1
# ¿Ya tiene la altura en metros?
# 1.si
# 2.No  2
# Seleccione en que forma lo tiene:
# 1.Km
# 2.Hm
# 3.Dm
# 4.dm
# 5.cm
# 6.mm4
# Ingrese los decimetros: 23
# La velocidad final es: 1 M/s
#
# Gracias por utilizar nuestros servicios, siguenos en instagram como ARMITH16 <3
