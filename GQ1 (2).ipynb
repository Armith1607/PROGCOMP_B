# %%
import time
nombre=input("Ingresa tu nombre: ")
print(f"Hola {nombre}, vamos a aprender jugando al ahorcado <3")
print()
time.sleep(1)
print("Comienza a adivinar")
time.sleep(0.5)
print("Pista: es la capital de Canadá ")
palabra='Ottawa'
palabra2='Eniac'
palabra3='Burundi'
palabra4='Elon Musk'
palabra5="Mark Zuckerberg"
tupalabra=''
vidas=5

while vidas >0:

  fallas=0
  for letra in palabra:
    if letra in tupalabra:
      print(letra,end="")
    else:
        print("*",end="")
        fallas+=1
  if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

  tuletra=input("Introduce una letra: ")
  tupalabra+=tuletra

  if tuletra not in palabra:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
  if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra}")
else:
  print("Gracias por participar")

x=int(input("Espera, ¿quieres seguir jugando?: \n1.Si\n2.No"))
if x==2:
  print("Esta bien, que te vaya bien")
elif x==1:
  print("Pista: Es considerada historicamente la primera computadora del mundo")
  tupalabra=''
  while vidas >0:

    fallas=0
    for letra in palabra2:
      if letra in tupalabra:
       print(letra,end="")
      else:
        print("*",end="")
        fallas+=1
    if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

    tuletra=input("Introduce una letra: ")
    tupalabra+=tuletra

    if tuletra not in palabra2:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
    if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra2}")
  else:
   print("Gracias por participar")

y=int(input("Espera, ¿quieres seguir jugando?: \n1.Si\n2.No"))
if x==2:
  print("Esta bien, que te vaya bien")
elif x==1:
  print("Pista: Es el pais mas pobre del mundo :c")
  tupalabra=''
  while vidas >0:

    fallas=0
    for letra in palabra3:
      if letra in tupalabra:
       print(letra,end="")
      else:
        print("*",end="")
        fallas+=1
    if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

    tuletra=input("Introduce una letra: ")
    tupalabra+=tuletra

    if tuletra not in palabra3:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
    if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra3}")
  else:
   print("Gracias por participar")   

z=int(input("Espera, ¿quieres seguir jugando?: \n1.Si\n2.No"))
if x==2:
  print("Esta bien, que te vaya bien")
elif x==1:
  print("Pista: Es uno de los hombres más ricos actualmente")
  tupalabra=''
  while vidas >0:

    fallas=0
    for letra in palabra4:
      if letra in tupalabra:
       print(letra,end="")
      else:
        print("*",end="")
        fallas+=1
    if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

    tuletra=input("Introduce una letra: ")
    tupalabra+=tuletra

    if tuletra not in palabra4:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
    if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra4}")
  else:
   print("Gracias por participar")  

d=int(input("Espera, ¿quieres seguir jugando?: \n1.Si\n2.No"))
if x==2:
  print("Esta bien, que te vaya bien")
elif x==1:
  print("Pista: Creador de Facebook (Meta)")
  tupalabra=''
  while vidas >0:

    fallas=0
    for letra in palabra5:
      if letra in tupalabra:
       print(letra,end="")
      else:
        print("*",end="")
        fallas+=1
    if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

    tuletra=input("Introduce una letra: ")
    tupalabra+=tuletra

    if tuletra not in palabra5:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
    if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra5}")
  else:
   print("Gracias por participar, \nLamento decirtelo mi rey pero hasta aca llegamos, By Armith corporations")
# Out:
# Ingresa tu nombre: armith
# Hola armith, vamos a aprender jugando al ahorcado <3
#
# Comienza a adivinar
# Pista: es la capital de Canadá
# ******Introduce una letra: O
# O*****Introduce una letra: t
# Ott***Introduce una letra: w
# Ott*w*Introduce una letra: a
# Ottawa
# Felicidades, Ganaste
# Espera, ¿quieres seguir jugando?:
# 1.Si
# 2.No1
# Pista: Es considerada historicamente la primera computadora del mundo
# *****Introduce una letra: E
# E****Introduce una letra: n
# En***Introduce una letra: i
# Eni**Introduce una letra: a
# Enia*Introduce una letra: c
# Eniac
# Felicidades, Ganaste
# Espera, ¿quieres seguir jugando?:
# 1.Si
# 2.No1
# Pista: Es el pais mas pobre del mundo :c
# *******Introduce una letra: d
# *****d*Introduce una letra: u
# *u*u*d*Introduce una letra: n
# *u*und*Introduce una letra: s
# Te equivocaste
# Tienes 4 vidas
# *u*und*Introduce una letra: a
# Te equivocaste
# Tienes 3 vidas
# *u*und*Introduce una letra: B
# Bu*und*Introduce una letra: r
# Burund*Introduce una letra: i
# Burundi
# Felicidades, Ganaste
# Espera, ¿quieres seguir jugando?:
# 1.Si
# 2.No1
# Pista: Es uno de los hombres más ricos actualmente
# *********Introduce una letra: E
# E********Introduce una letra: l
# El*******Introduce una letra: o
# Elo******Introduce una letra: n
# Elon*****Introduce una letra:
# Elon ****Introduce una letra: M
# Elon M***Introduce una letra: u
# Elon Mu**Introduce una letra: s
# Elon Mus*Introduce una letra: k
# Elon Musk
# Felicidades, Ganaste
# Espera, ¿quieres seguir jugando?:
# 1.Si
# 2.No1
# Pista: Creador de Facebook (Meta)
# ***************Introduce una letra: M
# M**************Introduce una letra: a
# Ma*************Introduce una letra: r
# Mar*******r**r*Introduce una letra: k
# Mark****k*r**r*Introduce una letra: p
# Te equivocaste
# Tienes 2 vidas
# Mark****k*r**r*Introduce una letra:
# Mark ***k*r**r*Introduce una letra: Z
# Mark Z**k*r**r*Introduce una letra: u
# Mark Zu*k*r**r*Introduce una letra: k
# Mark Zu*k*r**r*Introduce una letra: k
# Mark Zu*k*r**r*Introduce una letra: c
# Mark Zuck*r**r*Introduce una letra: b
# Mark Zuck*rb*r*Introduce una letra: e
# Mark Zuckerber*Introduce una letra: g
# Mark Zuckerberg
# Felicidades, Ganaste
