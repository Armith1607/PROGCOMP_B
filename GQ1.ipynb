# %%
import time
nombre=input("Ingresa tu nombre: ")
print(f"Hola {nombre}, vamos a aprender jugando al ahorcado <3")
print()
time.sleep(1)
print("Comienza a adivinar")
time.sleep(0.5)
print("Pista: es la capital de Canadá ")
palabra='Ottawa'
palabra2='Eniac'
palabra3='Burundi'
palabra4='Elon Musk'
palabra5="Mark Zuckerberg"
tupalabra=''
vidas=5

while vidas >0:

  fallas=0
  for letra in palabra:
    if letra in tupalabra:
      print(letra,end="")
    else:
        print("*",end="")
        fallas+=1
  if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

  tuletra=input("Introduce una letra: ")
  tupalabra+=tuletra

  if tuletra not in palabra:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
  if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra}")
else:
  print("Gracias por participar")

x=int(input("Espera, ¿quieres seguir jugando?: \n1.Si\n2.No"))
if x==2:
  print("Esta bien, que te vaya bien")
elif x==1:
  print("Pista: Es considerada historicamente la primera computadora del mundo}")
  while vidas >0:

    fallas=0
    for letra in palabra2:
      if letra in tupalabra:
       print(letra,end="")
      else:
        print("*",end="")
        fallas+=1
    if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

    tuletra=input("Introduce una letra: ")
    tupalabra+=tuletra

    if tuletra not in palabra2:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
    if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra2}")
  else:
   print("Gracias por participar")

y=int(input("Espera, ¿quieres seguir jugando?: \n1.Si\n2.No"))
if x==2:
  print("Esta bien, que te vaya bien")
elif x==1:
  print("Pista: Es el pais mas pobre del mundo :c")
  while vidas >0:

    fallas=0
    for letra in palabra3:
      if letra in tupalabra:
       print(letra,end="")
      else:
        print("*",end="")
        fallas+=1
    if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

    tuletra=input("Introduce una letra: ")
    tupalabra+=tuletra

    if tuletra not in palabra3:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
    if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra3}")
  else:
   print("Gracias por participar")   

z=int(input("Espera, ¿quieres seguir jugando?: \n1.Si\n2.No"))
if x==2:
  print("Esta bien, que te vaya bien")
elif x==1:
  print("Pista: Es uno de los hombres más ricos actualmente")
  while vidas >0:

    fallas=0
    for letra in palabra4:
      if letra in tupalabra:
       print(letra,end="")
      else:
        print("*",end="")
        fallas+=1
    if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

    tuletra=input("Introduce una letra: ")
    tupalabra+=tuletra

    if tuletra not in palabra4:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
    if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra4}")
  else:
   print("Gracias por participar")  

d=int(input("Espera, ¿quieres seguir jugando?: \n1.Si\n2.No"))
if x==2:
  print("Esta bien, que te vaya bien")
elif x==1:
  print("Pista: Creador de Facebook (Meta)")
  while vidas >0:

    fallas=0
    for letra in palabra5:
      if letra in tupalabra:
       print(letra,end="")
      else:
        print("*",end="")
        fallas+=1
    if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

    tuletra=input("Introduce una letra: ")
    tupalabra+=tuletra

    if tuletra not in palabra5:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
    if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra5}")
  else:
   print("Gracias por participar") 
   print("\nLamento decirtelo mi rey pero hasta aca llegamos")
# Out:
# Ingresa tu nombre: armith
# Hola armith, vamos a aprender jugando al ahorcado <3
#
# Comienza a adivinar
# Pista: es la capital de Canadá
# ******Introduce una letra: O
# O*****Introduce una letra: t
# Ott***Introduce una letra: a
# Otta*aIntroduce una letra: w
# Ottawa
# Felicidades, Ganaste
# Espera, ¿quieres seguir jugando?:
# 1.Si
# 2.No1
# Pista: Es considerada historicamente la primera computadora del mundo
# ***a*Introduce una letra: i
# **ia*Introduce una letra: w
# Te equivocaste
# Tienes 4 vidas
# **ia*Introduce una letra: q
# Te equivocaste
# Tienes 3 vidas
# **ia*Introduce una letra: a
# **ia*Introduce una letra: r
# Te equivocaste
# Tienes 2 vidas
# **ia*Introduce una letra: E
# E*ia*Introduce una letra: n
# Enia*Introduce una letra: i
# Enia*Introduce una letra: c
# Eniac
# Felicidades, Ganaste
# Espera, ¿quieres seguir jugando?:
# 1.Si
# 2.No1
# Pista: Es el pais mas pobre del mundo :c
# **r*n*iIntroduce una letra: B
# B*r*n*iIntroduce una letra: u
# ...

# %%
import time
nombre=input("Ingresa tu nombre: ")
print(f"Hola {nombre}, vamos a aprender sobre geografia jugando al ahorcado <3")
print()
time.sleep(1)
print("Comienza a adivinar")
time.sleep(0.5)
print("Pista: es la capital de Canadá ")
palabra='Ottawa'
palabra3='Burundi'
palabra4='Brasil'
palabra5='Rusia'
tupalabra=''
vidas=5

while vidas >0:

  fallas=0
  for letra in palabra:
    if letra in tupalabra:
      print(letra,end="")
    else:
        print("*",end="")
        fallas+=1
  if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

  tuletra=input("Introduce una letra: ")
  tupalabra+=tuletra

  if tuletra not in palabra:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
  if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra}")
else:
  x=int(input("Espera, ¿quieres seguir jugando?: \n1.Si\n2.No"))
  if x==2:
   print("Esta bien, que te vaya bien")
  elif x==1:
   palabra2='China'
   print("Pista: Es el pais mas poblado actualmente")
  while vidas >0:

    fallas=0
    for letra in palabra2:
      if letra in tupalabra:
       print(letra,end="")
      else:
        print("*",end="")
        fallas+=1
    if fallas==0:
     print()
     print("Felicidades, Ganaste")
     break

    tuletra=input("Introduce una letra: ")
    tupalabra+=tuletra

    if tuletra not in palabra2:
     vidas-=1
     print("Te equivocaste")
     print(f"Tienes {+vidas} vidas ")
    if vidas==0:
     print("Perdiste")
     print(f"La palabra correcta era {palabra2}")
  else:
   print("Gracias por participar")
# Out:
# Ingresa tu nombre: hjkg
# Hola hjkg, vamos a aprender sobre geografia jugando al ahorcado <3
#
# Comienza a adivinar
# Pista: es la capital de Canadá
# ******Introduce una letra: O
# O*****Introduce una letra: t
# Ott***Introduce una letra: w
# Ott*w*Introduce una letra: a
# Ottawa
# Felicidades, Ganaste
